.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3E4iJ9WQFvg.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3e6KRIFvEVk.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3ELG8cKA0Pg.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3ElKuXGla14.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3f0YPwiWCeA.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3F6Ns3cfHzg.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3fdxoJJHIcU.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3FE8j7NBfbU.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3fetoAzGGU0.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3FNFBol_qao.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3FqdMmtDv0M.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3GC_BomLN6g.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3gclWYGxt_I.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3givR1cBmhM.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3gulS7rVSJY.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3gvLWl_uAgg.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3H-2dL4s_To.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3h8alM9W9Ko.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3hdME9T8MsY.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3helsczqbo4.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3HhDhEdbABE.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3hL98puNFic.wav
#   inflating: pygender/test_data/AudioSet/male_clips/3HNIwgQyelc.wav
#    creating: pygender/train_data/
#    creating: pygender/train_data/youtube/
#    creating: pygender/train_data/youtube/female/
#   inflating: pygender/train_data/youtube/female/female1.wav
#   inflating: pygender/train_data/youtube/female/female2.wav
#   inflating: pygender/train_data/youtube/female/female3.wav
#   inflating: pygender/train_data/youtube/female/female4.wav
#   inflating: pygender/train_data/youtube/female/female5.wav
#    creating: pygender/train_data/youtube/male/
#   inflating: pygender/train_data/youtube/male/male1.wav
#   inflating: pygender/train_data/youtube/male/male2.wav
#   inflating: pygender/train_data/youtube/male/male3.wav
#   inflating: pygender/train_data/youtube/male/male4.wav
#   inflating: pygender/train_data/youtube/male/male5.wav

# %% [markdown]
# # Voice Gender Detection using GMMs : A Python Primer
#
# The below data-sets can be downloaded from here.
#
#   Training corpus : It has been developed from YouTube videos and consists of 5 minutes of speech for each gender, spoken by 5 distinct male and 5 female speakers (i.e, 1 minute/speaker).
#
#   Test corpus: It has been extracted from “AudioSet“, a large scale manually annotated corpus recently released by Google this year (2017). The subset constructed from it contains 558 female only speech utterances and 546 male only speech utterances. All audio files are of 10 seconds duration and are sampled at 16000 Hz.

# %% [markdown]
# We will give a brief primer about how to work with speech signals. From the speech signals in training data, a popular speech feature, Mel Frequency Cepstrum Coefficients (MFCCs), will be extracted; they are known to contain gender information (among other things). The 2 gender models are built by using yet another famous ML technique – Gaussian Mixture Models (GMMs). A GMM will take as input the MFCCs of the training samples and will try to learn their distribution, which will be representative of the gender. Now, when the gender of a new voice sample is to be detected, first the MFCCs of the sample will be extracted and then the trained GMM models will be used to calculate the scores of the features for both the models. Model with the maximum score is predicted as gender of the test speech. Having given an overview of the approach, presented following is the organisation of this blog post:

# %% [markdown]
# # 1. Working with speech frames
#
# A speech signal is just a sequence of numbers which denote the amplitude of the speech spoken by the speaker. We need to understand 3 core concepts while working with speech signals:
#
#   Framing – Since speech is a non-stationary signal, its frequency contents are continuously changing with time. In order to do any sort of analysis of the signal, such as knowing its frequency contents for short time intervals (known as Short Term Fourier Transform of the signal), we need to be able to view it as a stationary signal. To achieve this stationarity, the speech signal is divided into short frames of duration 20 to 30 milliseconds, as the shape of our vocal tract can be assumed to be unvarying for such small intervals of time. Frames shorter than this duration won’t have enough samples to give a good estimate of the frequency components, while in longer frames the signal may change too much within the frame that the condition of stationary no more holds.

# %% [markdown]
# Windowing – Extracting raw frames from a speech signal can lead to discontinuities towards the endpoints due to non-integer number of periods in the extracted waveform, which will then lead to an erroneous frequency representation (known as spectral leakage in signal processing lingo). This is prevented by multiplying a window function with the speech frame. A window function’s amplitude gradually falls to zero towards its two end and thus this multiplication minimizes the amplitude of the above mentioned discontinuities.

# %% [markdown]
# Overlapping frames – Due to windowing, we are actually losing the samples towards the beginning and the end of the frame; this too will lead to an incorrect frequency representation. To compensate for this loss, we take overlapping frames rather than disjoint frames, so that the samples lost from the end of the ith frame and the beginning of the (i+1)th frame are wholly included in the frame formed by the overlap between these 2 frames. The overlap between frames is generally taken to be of 10-15 ms.

# %% [markdown]
# # 2. Extracting MFCC features
#
# Having extracted the speech frames, we now proceed to derive MFCC features for each speech frame.  Speech is produced by humans by filtering applied by our vocal tract on the air expelled by our lungs. The properties of the source (lungs) are common for all speakers; it is the properties of the vocal tract, which is responsible for giving shape to the spectrum of signal and it varies across speakers. The shape of the vocal tract governs what sound is produced and the MFCCs best represent this shape.
#
# MFCCs are mel-frequency cepstral coefficients which are some transformed values of signal in cepstral domain. From theory of speech production, speech is assumed to be convolution of source (air expelled from lungs) and filter (our vocal tract). The purpose here is to characterise the filter and remove the source part. In order to achieve this,

# %% [markdown]
#   We first transform the time domain speech signal into spectral domain signal using Fourier transform where source and filter part are now in multiplication.
#
#   Take log of the transformed values so that source and filter are now additive in log spectral domain. Use of log to transform from multiplication to summation made it easy to separate source and filter using a linear filter.
#
#   Finally, we apply discrete cosine transform (found to be more successful than FFT or I-FFT) of the log spectral signal to get MFCCs. Initially the idea was to transform the log spectral signal to time domain using Inverse-FFT but ‘log’ being a non-linear operation created new frequencies called Quefrency or say it transformed the log spectral signal into a new domain called cepstral domain (ceps being reverse of spec).
#
#   The reason for the term ‘mel’ in MFFC is mel scale which exactly specifies how to space our frequency regions. Humans are much better at discerning small changes in pitch at low frequencies than they are at high frequencies. Incorporating this scale makes our features match more closely what humans hear.
#
# The above explanation is just to give the readers an idea of how these features were motivated. If you really like to explore and understand more about MFCCs, you can read in this blog. You can find various implementation for extracting MFCCs on internet. We have employed python_speech_features (check here). All you have to do is pip install python_speech_features. One can also install scikits talkbox for the same. The following python code is a function to extract MFCC features from given audio.

# %%
! pip install cPickle
# Out:
# ERROR: Could not find a version that satisfies the requirement cPickle (from versions: none)
# ERROR: No matching distribution found for cPickle

# %%
import python_speech_features as mfcc
def get_MFCC(sr,audio):
    features = mfcc.mfcc(audio, sr, 0.025, 0.01, 13, appendEnergy = False)
    features = preprocessing.scale(features)
    return features

# %% [markdown]
# # 3. Training gender models
#
# In order to build a gender detection system from the above extracted features, we need to model both the genders. We employ GMMs for this task.
#
# A Gaussian mixture model is a probabilistic clustering model for representing the presence of sub-populations within an overall population.  The idea of training a GMM is to approximate the probability distribution of a class by a linear combination of ‘k’ Gaussian distributions/clusters, also called the components of the GMM. The likelihood of data points (feature vectors) for a model is given by following equation:

# %% [markdown]
# Python’s sklearn.mixture package is used by us to learn a GMM from the features matrix containing the MFCC features. The GMM object requires the number of components n_components to be fitted on the data, the number of iterations n_iter to be performed for estimating the parameters of these n components, the type of co-variance covariance_type to be assumed between the features and the number of times n_ init the K-means initialization is to be done. The initialization which gave the best results is kept. The fit() function then estimates the model parameters using the EM algorithm.
#
# The following Python code is used to train the gender models. The code is run once for each gender and source is given the path to the training files for the respective gender.

# %%
from sklearn.mixture import GMM
gmm = GMM(n_components = 8, n_iter = 200, covariance_type='diag',n_init = 3)
gmm.fit(features)

# %%
import os
import pickle
import numpy as np
from scipy.io.wavfile import read
from sklearn.mixture import GaussianMixture as GMM
import python_speech_features as mfcc
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
 
def get_MFCC(sr,audio):
    features = mfcc.mfcc(audio,sr, 0.025, 0.01, 13,appendEnergy = False)
    features = preprocessing.scale(features)
    return features
 
#path to training data
source   = "/content/pygender/train_data/youtube/male"
#path to save trained model
dest     = "/content/pygender"
files    = [os.path.join(source,f) for f in os.listdir(source) if
             f.endswith('.wav')]
features = np.asarray(());
 
for f in files:
    sr,audio = read(f)
    vector   = get_MFCC(sr,audio)
    if features.size == 0:
        features = vector
    else:
        features = np.vstack((features, vector))
 
gmm = GMM(n_components = 8, covariance_type='diag',
        n_init = 3)
gmm.fit(features)
picklefile = f.split("/")[-2].split(".wav")[0]+".gmm"
 
# model saved as male.gmm
filename = '/content/pygender/Male.gmm'
outfile = open(filename,'wb')
pickle.dump(gmm, outfile)
outfile.close()
print('modeling completed for gender:',picklefile)
# Out:
# modeling completed for gender: male.gmm

# %%
import os
import pickle
import numpy as np
from scipy.io.wavfile import read
from sklearn.mixture import GaussianMixture as GMM
import python_speech_features as mfcc
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
 
def get_MFCC(sr,audio):
    features = mfcc.mfcc(audio,sr, 0.025, 0.01, 13,appendEnergy = False)
    features = preprocessing.scale(features)
    return features
 
#path to training data
source   = "/content/pygender/train_data/youtube/female"
#path to save trained model
dest     = "/content/pygender"
files    = [os.path.join(source,f) for f in os.listdir(source) if
             f.endswith('.wav')]
features = np.asarray(());
 
for f in files:
    sr,audio = read(f)
    vector   = get_MFCC(sr,audio)
    if features.size == 0:
        features = vector
    else:
        features = np.vstack((features, vector))
 
gmm = GMM(n_components = 8, covariance_type='diag',
        n_init = 3)
gmm.fit(features)
picklefile = f.split("/")[-2].split(".wav")[0]+".gmm"
 
# model saved as male.gmm
filename = '/content/pygender/Female.gmm'
outfile = open(filename,'wb')
pickle.dump(gmm, outfile)
outfile.close()
print('modeling completed for gender:',picklefile)
# Out:
# modeling completed for gender: female.gmm

# %% [markdown]
# # 4. Evaluation on subset of AudioSet corpus
#
# Upon arrival of a test voice sample for gender detection, we begin by extracting the MFCC features for it, with 25 ms frame size and 10 ms overlap between frames . Next we require the log likelihood scores for each frame of the sample, x_1, x_2, ... ,x_i , belonging to each gender, ie, P(x_i|female) and P(x_i|male) is to be calculated. Using (2), the likelihood of the frame being from a female voice is calculated by substituting the \mu and \Sigma of female GMM model. This is done for each of the k Gaussian components in the model, and the weighted  sum of the k likelihoods from the components is taken as per the w parameter of the model, just like in (1). The logarithm operation when applied on the obtained sum gives us the log likelihood value for the frame. This is repeated for all the frames of the sample and the likelihoods of all the frames are added.
#
# Similar to this, the likelihood of the speech being male is calculated by substituting the values of the parameters of the trained male GMM model and repeating the above procedure for all the frames. The Python code given below predicts the gender of the test audio.

# %%
import os
import pickle
import numpy as np
from scipy.io.wavfile import read
import python_speech_features as mfcc
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
def get_MFCC(sr,audio):
    features = mfcc.mfcc(audio,sr, 0.025, 0.01, 13,appendEnergy = False)
    feat     = np.asarray(())
    for i in range(features.shape[0]):
        temp = features[i,:]
        if np.isnan(np.min(temp)):
            continue
        else:
            if feat.size == 0:
                feat = temp
            else:
                feat = np.vstack((feat, temp))
    features = feat;
    features = preprocessing.scale(features)
    return features
 
#path to test data
sourcepath = "/content/pygender/test_data/AudioSet/female_clips"
#path to saved models
modelpath  = "/content/pygender"    
 
gmm_files = [os.path.join(modelpath,fname) for fname in
              os.listdir(modelpath) if fname.endswith('.gmm')]
models    = [pickle.load(open(fname,'rb')) for fname in gmm_files]
genders   = [fname.split("/")[-1].split(".gmm")[0] for fname
              in gmm_files]
files     = [os.path.join(sourcepath,f) for f in os.listdir(sourcepath)
              if f.endswith(".wav")] 
total_file=0
correct=0
wrong=0
for f in files:
    #print(f.split("/")[-1])
    total_file+=1
    sr, audio  = read(f)
    features   = get_MFCC(sr,audio)
    scores     = None
    log_likelihood = np.zeros(len(models))
    for i in range(len(models)):
        gmm    = models[i]         #checking with each model one by one
        scores = np.array(gmm.score(features))
        log_likelihood[i] = scores.sum()
    winner = np.argmax(log_likelihood)
    if(genders[winner]=='Female'):
      correct+=1
    else:
      wrong+=1
    #print("\tdetected as - ", genders[winner],"\n\tscores:female ",log_likelihood[0],",male ", log_likelihood[1],"\n")
print("total no of files = ",total_file)
print("Correctly identified files = ", correct)
print("Wrong identification = ", wrong)
# Out:
# total no of files =  558
# Correctly identified files =  531
# Wrong identification =  27

# %%
import os
import pickle
import numpy as np
from scipy.io.wavfile import read
import python_speech_features as mfcc
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
def get_MFCC(sr,audio):
    features = mfcc.mfcc(audio,sr, 0.025, 0.01, 13,appendEnergy = False)
    feat     = np.asarray(())
    for i in range(features.shape[0]):
        temp = features[i,:]
        if np.isnan(np.min(temp)):
            continue
        else:
            if feat.size == 0:
                feat = temp
            else:
                feat = np.vstack((feat, temp))
    features = feat;
    features = preprocessing.scale(features)
    return features
 
#path to test data
sourcepath = "/content/pygender/test_data/AudioSet/male_clips"
#path to saved models
modelpath  = "/content/pygender"    
 
gmm_files = [os.path.join(modelpath,fname) for fname in
              os.listdir(modelpath) if fname.endswith('.gmm')]
models    = [pickle.load(open(fname,'rb')) for fname in gmm_files]
genders   = [fname.split("/")[-1].split(".gmm")[0] for fname
              in gmm_files]
files     = [os.path.join(sourcepath,f) for f in os.listdir(sourcepath)
              if f.endswith(".wav")] 
total_file=0
correct=0
wrong=0
for f in files:
    #print(f.split("/")[-1])
    total_file+=1
    sr, audio  = read(f)
    features   = get_MFCC(sr,audio)
    scores     = None
    log_likelihood = np.zeros(len(models))
    for i in range(len(models)):
        gmm    = models[i]         #checking with each model one by one
        scores = np.array(gmm.score(features))
        log_likelihood[i] = scores.sum()
    winner = np.argmax(log_likelihood)
    if(genders[winner]=='Male'):
      correct+=1
    else:
      wrong+=1
    #print("\tdetected as - ", genders[winner],"\n\tscores:female ",log_likelihood[0],",male ", log_likelihood[1],"\n")
print("total no of files = ",total_file)
print("Correctly identified files = ", correct)
print("Wrong identification = ", wrong)
# Out:
# total no of files =  546
# Correctly identified files =  414
# Wrong identification =  132

# %% [markdown]
# http://www.primaryobjects.com/2016/06/22/identifying-the-gender-of-a-voice-using-machine-learning/

# %% [markdown]
# Concluding Remarks
#
# We hope the blog post was successful in explaining to you your first speech processing task. We expect you to reproduce the results posted by us. In order to get a better understanding of the various parameters used by us, you can play with them, for example:
#
#   Train gender models on larger data-set. In the experiments performed, training data consists of  5 minutes of speech per gender only. A larger data-set may improve the accuracy as it will encompass the MFCCs well.
#
#   Clean the extracted data-set from AudioSet. We have not done any cleaning or noise removal. Few of the audios are noisy and the spoken speech part in audio is less in the 10 seconds audio clip.
#
#   Readers can study the effect of number of GMM components on the performance of the models.
#
#   We have taken only MFCCs in order to build a gender detection system. In literature, you can find lot of acoustic features that are used to build gender model. For reference here is a link.

# %%
a=10

# %% [markdown]
# # Spoken Speaker Identification based on Gaussian Mixture Models : Python Implementation

# %% [markdown]
# Similar to our previous post “Voice Gender Detection“, this blog-post focuses on a beginner’s method to answer the question ‘who is the speaker‘ in the speech file. Recently, lot of voice biometric systems have been developed which can extract speaker information from the recorded voice and identify the speaker from set of trained speakers in the database. In this blog-post, we will illustrate the same with a naive approach using Gaussian Mixture Models (GMM). There are other conventional as well as modern approaches which are more robust to channel noise and also performs better than approach followed in this blog-post.
#
#     GMM-UBM (Gaussian Mixture Model – Universal Background Model) using MAP (Maximum Aposteriori) adaptation [1] is one of the successful conventional technique to implement speaker identification.
#     I-vectors based speaker identification [2] is the state-of-the-art technique implemented in lot of voice biometric products.
#
# As a beginner, the above mentioned techniques may overwhelm you as they are mathematically complex methods and requires some research effort in order to comprehend. Therefore, I am not following any of the two approaches. Instead, I am interested in showing you the implementation of fundamental step of speaker identification (using GMMs) which can then lead to development of GMM-UBM or I-vectors approach.

# %%
! wget https://www.dropbox.com/s/k89d0cd0dfeikh6/development_set.zip?dl=0
# Out:
# --2020-05-15 05:13:09--  https://www.dropbox.com/s/k89d0cd0dfeikh6/development_set.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/k89d0cd0dfeikh6/development_set.zip [following]
# --2020-05-15 05:13:09--  https://www.dropbox.com/s/raw/k89d0cd0dfeikh6/development_set.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com/cd/0/inline/A3s59AYod-ERzaY7R6k4FD63hgNF1QtuuXxQFkBjqij9m3TVxUE54tZD3B2MBmP8vuzxCXMiWU6OPRniY88hE6VCSw15cBYZujY61VPvO4J0UYusTO2nEmF5ok5U_15VzMo/file# [following]
# --2020-05-15 05:13:10--  https://ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com/cd/0/inline/A3s59AYod-ERzaY7R6k4FD63hgNF1QtuuXxQFkBjqij9m3TVxUE54tZD3B2MBmP8vuzxCXMiWU6OPRniY88hE6VCSw15cBYZujY61VPvO4J0UYusTO2nEmF5ok5U_15VzMo/file
# Resolving ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com (ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com (ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/A3tM_8z59h7oUySNHvx1Dt6cf-Je28RcXwxAvqPpuBOLgGQYzDTTqXNKuiiSq8gW-PWO4s2kFdCM6fYaoTPvSMBTl_4Yf6vAxTW9nATzXv6bUMmpVp3S1teffNKupphj7cCdmeTKgs-mkWVyDLc7GDkampPVFE-7J4bFdyzMTIwOGxDHq-vQo1G5a_opU8y9WF72UDYbJHU-TT9OCU-Cooh-4fYDXm51eJVJiI-mFrOOBRNHb8pbXlQJQGha6lY3fPpkJAK_GVcGLnY2BbJjL5ClXxrad66lrc2MMIzjhNfCBJisifS8m9aXfxCM77QjIp3RNIKXfbsYWT-ESo2I6ZQyxEDceBNzKwu38NVhXyEkiA/file [following]
# --2020-05-15 05:13:10--  https://ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com/cd/0/inline2/A3tM_8z59h7oUySNHvx1Dt6cf-Je28RcXwxAvqPpuBOLgGQYzDTTqXNKuiiSq8gW-PWO4s2kFdCM6fYaoTPvSMBTl_4Yf6vAxTW9nATzXv6bUMmpVp3S1teffNKupphj7cCdmeTKgs-mkWVyDLc7GDkampPVFE-7J4bFdyzMTIwOGxDHq-vQo1G5a_opU8y9WF72UDYbJHU-TT9OCU-Cooh-4fYDXm51eJVJiI-mFrOOBRNHb8pbXlQJQGha6lY3fPpkJAK_GVcGLnY2BbJjL5ClXxrad66lrc2MMIzjhNfCBJisifS8m9aXfxCM77QjIp3RNIKXfbsYWT-ESo2I6ZQyxEDceBNzKwu38NVhXyEkiA/file
# Reusing existing connection to ucbb3f066fe51157bbc0d888f876.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 277265901 (264M) [application/zip]
# Saving to: ‘development_set.zip?dl=0’
#
# development_set.zip 100%[===================>] 264.42M  60.5MB/s    in 4.3s
#
# 2020-05-15 05:13:15 (61.3 MB/s) - ‘development_set.zip?dl=0’ saved [277265901/277265901]

# %%
! unzip '/content/development_set.zip'
# Out:
# Archive:  /content/development_set.zip
#    creating: development_set/
#    creating: development_set/bhart-20100106-lpu/
#   inflating: development_set/bhart-20100106-lpu/LICENSE
#    creating: development_set/bhart-20100106-ldp/
#   inflating: development_set/bhart-20100106-ldp/LICENSE
#    creating: development_set/bhart-20100106-kab/
#   inflating: development_set/bhart-20100106-kab/LICENSE
#    creating: development_set/bhart-20100106-jot/
#   inflating: development_set/bhart-20100106-jot/LICENSE
#    creating: development_set/bhart-20100106-joc/
#   inflating: development_set/bhart-20100106-joc/LICENSE
#    creating: development_set/bhart-20100106-giy/
#   inflating: development_set/bhart-20100106-giy/LICENSE
#    creating: development_set/bhart-20100106-djk/
#   inflating: development_set/bhart-20100106-djk/LICENSE
#    creating: development_set/BFG-20120316-bdl/
#   inflating: development_set/BFG-20120316-bdl/LICENSE
#    creating: development_set/Berrym-20101102-aiv/
#   inflating: development_set/Berrym-20101102-aiv/LICENSE
#    creating: development_set/benoliver999-20100207-jxe/
#   inflating: development_set/benoliver999-20100207-jxe/LICENSE
#    creating: development_set/benoliver999-20100207-euk/
#   inflating: development_set/benoliver999-20100207-euk/LICENSE
#    creating: development_set/benob-20090314-wzw/
#   inflating: development_set/benob-20090314-wzw/LICENSE
#    creating: development_set/bennmann-20091102-vgn/
#   inflating: development_set/bennmann-20091102-vgn/LICENSE
#    creating: development_set/bennmann-20091102-ksm/
#   inflating: development_set/bennmann-20091102-ksm/LICENSE
#    creating: development_set/bennmann-20091102-apc/
#   inflating: development_set/bennmann-20091102-apc/LICENSE
#    creating: development_set/bendra-20141108-xnz/
#   inflating: development_set/bendra-20141108-xnz/LICENSE
#    creating: development_set/bendauphinee-20100503-zmm/
#   inflating: development_set/bendauphinee-20100503-zmm/LICENSE
#    creating: development_set/bendauphinee-20100423-vvc/
#   inflating: development_set/bendauphinee-20100423-vvc/LICENSE
#    creating: development_set/bendauphinee-20100423-rlg/
#   inflating: development_set/bendauphinee-20100423-rlg/LICENSE
#    creating: development_set/bendauphinee-20100423-guj/
#   inflating: development_set/bendauphinee-20100423-guj/LICENSE
#    creating: development_set/bendauphinee-20100423-dtj/
#   inflating: development_set/bendauphinee-20100423-dtj/LICENSE
#    creating: development_set/bencoder-20080418-ivd/
#   inflating: development_set/bencoder-20080418-ivd/LICENSE
#    creating: development_set/bencoder-20080418-iev/
#   inflating: development_set/bencoder-20080418-iev/LICENSE
#    creating: development_set/ben-20090326-njk/
#   inflating: development_set/ben-20090326-njk/LICENSE
#    creating: development_set/ben-20090326-hxc/
#   inflating: development_set/ben-20090326-hxc/LICENSE
#    creating: development_set/ben-20090326-cpr/
#   inflating: development_set/ben-20090326-cpr/LICENSE
#    creating: development_set/belmontguy-20110426-geu/
#   inflating: development_set/belmontguy-20110426-geu/LICENSE
#    creating: development_set/beez1717-20111017-yqm/
#   inflating: development_set/beez1717-20111017-yqm/LICENSE
#    creating: development_set/becz03-20121205-yzd/
#   inflating: development_set/becz03-20121205-yzd/LICENSE
#    creating: development_set/becz03-20121205-xvx/
#   inflating: development_set/becz03-20121205-xvx/LICENSE
#    creating: development_set/becz03-20121205-ixj/
#   inflating: development_set/becz03-20121205-ixj/LICENSE
#    creating: development_set/bebe-20100421-xjv/
#   inflating: development_set/bebe-20100421-xjv/LICENSE
#    creating: development_set/bebe-20100419-wtr/
#   inflating: development_set/bebe-20100419-wtr/LICENSE
#    creating: development_set/bebe-20100419-tst/
#   inflating: development_set/bebe-20100419-tst/LICENSE
#    creating: development_set/bebe-20100419-nrh/
#   inflating: development_set/bebe-20100419-nrh/LICENSE
#    creating: development_set/bebe-20100419-gpw/
#   inflating: development_set/bebe-20100419-gpw/LICENSE
#    creating: development_set/beady-20100219-xpq/
#   inflating: development_set/beady-20100219-xpq/LICENSE
#    creating: development_set/bdutta-20090502-vrk/
#   inflating: development_set/bdutta-20090502-vrk/LICENSE
#    creating: development_set/bdutta-20090502-uzt/
#   inflating: development_set/bdutta-20090502-uzt/LICENSE
#    creating: development_set/bdutta-20090502-crj/
#   inflating: development_set/bdutta-20090502-crj/LICENSE
#    creating: development_set/Bassel-20120209-xky/
#   inflating: development_set/Bassel-20120209-xky/LICENSE
#    creating: development_set/bart-20090807-ufp/
#   inflating: development_set/bart-20090807-ufp/LICENSE
#    creating: development_set/Bareford-20101110-qkl/
#   inflating: development_set/Bareford-20101110-qkl/LICENSE
#    creating: development_set/Bahoke-20130721-zau/
#   inflating: development_set/Bahoke-20130721-zau/LICENSE
#    creating: development_set/Bahoke-20130721-wit/
#   inflating: development_set/Bahoke-20130721-wit/LICENSE
#    creating: development_set/Bahoke-20130721-uop/
#   inflating: development_set/Bahoke-20130721-uop/LICENSE
#    creating: development_set/Bahoke-20130721-unp/
#   inflating: development_set/Bahoke-20130721-unp/LICENSE
#    creating: development_set/Bahoke-20130721-sjx/
#   inflating: development_set/Bahoke-20130721-sjx/LICENSE
#    creating: development_set/Bahoke-20130721-qpx/
#   inflating: development_set/Bahoke-20130721-qpx/LICENSE
#    creating: development_set/Bahoke-20130721-mba/
#   inflating: development_set/Bahoke-20130721-mba/LICENSE
#    creating: development_set/Bahoke-20130721-jpg/
#   inflating: development_set/Bahoke-20130721-jpg/LICENSE
#    creating: development_set/Bahoke-20130721-iux/
#   inflating: development_set/Bahoke-20130721-iux/LICENSE
#    creating: development_set/Bahoke-20130721-hgw/
#   inflating: development_set/Bahoke-20130721-hgw/LICENSE
#    creating: development_set/Bahoke-20130721-brs/
#   inflating: development_set/Bahoke-20130721-brs/LICENSE
#    creating: development_set/bae-20110617-vdq/
#   inflating: development_set/bae-20110617-vdq/LICENSE
#    creating: development_set/bachroxx-20080119-tuu/
#   inflating: development_set/bachroxx-20080119-tuu/LICENSE
#    creating: development_set/B-20091230-yjo/
#   inflating: development_set/B-20091230-yjo/LICENSE
#    creating: development_set/B-20091230-umt/
#   inflating: development_set/B-20091230-umt/LICENSE
#    creating: development_set/B-20091230-bvx/
#   inflating: development_set/B-20091230-bvx/LICENSE
#    creating: development_set/B-20091223-lxu/
#   inflating: development_set/B-20091223-lxu/LICENSE
#    creating: development_set/B-20091221-pxt/
#   inflating: development_set/B-20091221-pxt/LICENSE
#    creating: development_set/B-20091220-zaq/
#   inflating: development_set/B-20091220-zaq/LICENSE
#    creating: development_set/B-20091220-vus/
#   inflating: development_set/B-20091220-vus/LICENSE
#    creating: development_set/azmisov-20140430-mqe/
#   inflating: development_set/azmisov-20140430-mqe/LICENSE
#    creating: development_set/azmisov-20140428-xml/
#   inflating: development_set/azmisov-20140428-xml/LICENSE
#    creating: development_set/azmisov-20140428-wjm/
#   inflating: development_set/azmisov-20140428-wjm/LICENSE
#    creating: development_set/azmisov-20140428-tth/
#   inflating: development_set/azmisov-20140428-tth/LICENSE
#    creating: development_set/azmisov-20140428-tqh/
#   inflating: development_set/azmisov-20140428-tqh/LICENSE
#    creating: development_set/azmisov-20140428-pdb/
#   inflating: development_set/azmisov-20140428-pdb/LICENSE
#    creating: development_set/azmisov-20140428-ovn/
#   inflating: development_set/azmisov-20140428-ovn/LICENSE
#    creating: development_set/azmisov-20140428-mjz/
#   inflating: development_set/azmisov-20140428-mjz/LICENSE
#    creating: development_set/azmisov-20140428-kfo/
#   inflating: development_set/azmisov-20140428-kfo/LICENSE
#    creating: development_set/azmisov-20140428-hgh/
#   inflating: development_set/azmisov-20140428-hgh/LICENSE
#    creating: development_set/azmisov-20140428-gjh/
#   inflating: development_set/azmisov-20140428-gjh/LICENSE
#    creating: development_set/azmisov-20140428-cyp/
#   inflating: development_set/azmisov-20140428-cyp/LICENSE
#    creating: development_set/axllaruse-20140112-ced/
#   inflating: development_set/axllaruse-20140112-ced/LICENSE
#    creating: development_set/ax-20150219-yhd/
#   inflating: development_set/ax-20150219-yhd/LICENSE
#    creating: development_set/avsa242-20071208/
#   inflating: development_set/avsa242-20071208/LICENSE
#    creating: development_set/audioodyssey-20081109-rew/
#   inflating: development_set/audioodyssey-20081109-rew/LICENSE
#    creating: development_set/atterer-21012007-vf22/
#   inflating: development_set/atterer-21012007-vf22/LICENSE
#    creating: development_set/atterer-20080108-wnr/
#   inflating: development_set/atterer-20080108-wnr/LICENSE
#    creating: development_set/atterer-20080108-dlc/
#   inflating: development_set/atterer-20080108-dlc/LICENSE
#    creating: development_set/atterer-20080102-qgo/
#   inflating: development_set/atterer-20080102-qgo/LICENSE
#    creating: development_set/atterer-20080101-xkv/
#   inflating: development_set/atterer-20080101-xkv/LICENSE
#    creating: development_set/atterer-20080101-qvo/
#   inflating: development_set/atterer-20080101-qvo/LICENSE
#    creating: development_set/atterer-20080101-gpr/
#   inflating: development_set/atterer-20080101-gpr/LICENSE
#    creating: development_set/atterer-20080101-bud/
#   inflating: development_set/atterer-20080101-bud/LICENSE
#    creating: development_set/atterer-02052007-vf5/
#   inflating: development_set/atterer-02052007-vf5/LICENSE
#    creating: development_set/atterer-01202007-b/
#   inflating: development_set/atterer-01202007-b/LICENSE
#    creating: development_set/atterer-01202007-a/
#   inflating: development_set/atterer-01202007-a/LICENSE
#    creating: development_set/ataru80-20120624-hfe/
#   inflating: development_set/ataru80-20120624-hfe/LICENSE
#    creating: development_set/atamur-20090211-wdo/
#   inflating: development_set/atamur-20090211-wdo/LICENSE
#    creating: development_set/AT-20130718-lws/
#   inflating: development_set/AT-20130718-lws/LICENSE
#    creating: development_set/asp-20091228-qtl/
#   inflating: development_set/asp-20091228-qtl/LICENSE
#    creating: development_set/asp-20091228-inn/
#   inflating: development_set/asp-20091228-inn/LICENSE
#    creating: development_set/AslakKnutsen-20140317-yil/
#   inflating: development_set/AslakKnutsen-20140317-yil/LICENSE
#    creating: development_set/AslakKnutsen-20140317-uly/
#   inflating: development_set/AslakKnutsen-20140317-uly/LICENSE
#    creating: development_set/AslakKnutsen-20140315-tkd/
#   inflating: development_set/AslakKnutsen-20140315-tkd/LICENSE
#    creating: development_set/AslakKnutsen-20140314-ukd/
#   inflating: development_set/AslakKnutsen-20140314-ukd/LICENSE
#    creating: development_set/AslakKnutsen-20140314-ube/
#   inflating: development_set/AslakKnutsen-20140314-ube/LICENSE
#    creating: development_set/AslakKnutsen-20140314-scx/
#   inflating: development_set/AslakKnutsen-20140314-scx/LICENSE
#    creating: development_set/AslakKnutsen-20140314-ogu/
#   inflating: development_set/AslakKnutsen-20140314-ogu/LICENSE
#    creating: development_set/AslakKnutsen-20140314-hwr/
#   inflating: development_set/AslakKnutsen-20140314-hwr/LICENSE
#    creating: development_set/AslakKnutsen-20140314-crb/
#   inflating: development_set/AslakKnutsen-20140314-crb/LICENSE
#    creating: development_set/AslakKnutsen-20140314-btr/
#   inflating: development_set/AslakKnutsen-20140314-btr/LICENSE
#    creating: development_set/AslakKnutsen-20140314-bje/
#   inflating: development_set/AslakKnutsen-20140314-bje/LICENSE
#    creating: development_set/asladic-20120219-qnd/
#   inflating: development_set/asladic-20120219-qnd/LICENSE
#    creating: development_set/asladic-20120203-uxq/
#   inflating: development_set/asladic-20120203-uxq/LICENSE
#    creating: development_set/asladic-20120203-jqc/
#   inflating: development_set/asladic-20120203-jqc/LICENSE
#    creating: development_set/asladic-20120203-eie/
#   inflating: development_set/asladic-20120203-eie/LICENSE
#    creating: development_set/asladic-20120203-dzz/
#   inflating: development_set/asladic-20120203-dzz/LICENSE
#    creating: development_set/asladic-20120203-dqw/
#   inflating: development_set/asladic-20120203-dqw/LICENSE
#    creating: development_set/asladic-20100311-tjx/
#   inflating: development_set/asladic-20100311-tjx/LICENSE
#    creating: development_set/asladic-20100311-bfp/
#   inflating: development_set/asladic-20100311-bfp/LICENSE
#    creating: development_set/asalkeld-20111226-ets/
#   inflating: development_set/asalkeld-20111226-ets/LICENSE
#    creating: development_set/arvala-20110103-nlb/
#   inflating: development_set/arvala-20110103-nlb/LICENSE
#    creating: development_set/arun-20100928-usw/
#   inflating: development_set/arun-20100928-usw/LICENSE
#    creating: development_set/artk-20101225-kvd/
#   inflating: development_set/artk-20101225-kvd/LICENSE
#    creating: development_set/arthur-20130509-yjj/
#   inflating: development_set/arthur-20130509-yjj/LICENSE
#    creating: development_set/Artem-20121123-ebd/
#   inflating: development_set/Artem-20121123-ebd/LICENSE
#    creating: development_set/armond-20121229-wca/
#   inflating: development_set/armond-20121229-wca/LICENSE
#    creating: development_set/arjuan-20100820-acz/
#   inflating: development_set/arjuan-20100820-acz/LICENSE
#    creating: development_set/ariyan-20120801-gra/
#   inflating: development_set/ariyan-20120801-gra/LICENSE
#    creating: development_set/argail-20090722-gau/
#   inflating: development_set/argail-20090722-gau/LICENSE
#    creating: development_set/Ara-20091021-wpl/
#   inflating: development_set/Ara-20091021-wpl/LICENSE
#    creating: development_set/Ara-20091020-vni/
#   inflating: development_set/Ara-20091020-vni/LICENSE
#    creating: development_set/Apple_Eater-20091026-yul/
#   inflating: development_set/Apple_Eater-20091026-yul/LICENSE
#    creating: development_set/anthonyschaller-20071221-/
#   inflating: development_set/anthonyschaller-20071221-/LICENSE
#    creating: development_set/bonzer-20090919-zyn/
#   inflating: development_set/bonzer-20090919-zyn/LICENSE
#    creating: development_set/bonzer-20090919-ztf/
#   inflating: development_set/bonzer-20090919-ztf/LICENSE
#    creating: development_set/bonzer-20090919-yes/
#   inflating: development_set/bonzer-20090919-yes/LICENSE
#    creating: development_set/bonzer-20090919-wgk/
#   inflating: development_set/bonzer-20090919-wgk/LICENSE
#    creating: development_set/bonzer-20090919-uzm/
#   inflating: development_set/bonzer-20090919-uzm/LICENSE
#    creating: development_set/bonzer-20090919-uln/
#   inflating: development_set/bonzer-20090919-uln/LICENSE
#    creating: development_set/bonzer-20090919-ukz/
#   inflating: development_set/bonzer-20090919-ukz/LICENSE
#    creating: development_set/bonzer-20090919-uin/
#   inflating: development_set/bonzer-20090919-uin/LICENSE
#    creating: development_set/bonzer-20090919-uda/
#   inflating: development_set/bonzer-20090919-uda/LICENSE
#    creating: development_set/bonzer-20090919-sdp/
#   inflating: development_set/bonzer-20090919-sdp/LICENSE
#    creating: development_set/bonzer-20090919-rxe/
#   inflating: development_set/bonzer-20090919-rxe/LICENSE
#    creating: development_set/bonzer-20090919-qcx/
#   inflating: development_set/bonzer-20090919-qcx/LICENSE
#    creating: development_set/bonzer-20090919-qbf/
#   inflating: development_set/bonzer-20090919-qbf/LICENSE
#    creating: development_set/bonzer-20090919-oxm/
#   inflating: development_set/bonzer-20090919-oxm/LICENSE
#    creating: development_set/bonzer-20090919-otm/
#   inflating: development_set/bonzer-20090919-otm/LICENSE
#    creating: development_set/bonzer-20090919-nzl/
#   inflating: development_set/bonzer-20090919-nzl/LICENSE
#    creating: development_set/bonzer-20090919-nxc/
#   inflating: development_set/bonzer-20090919-nxc/LICENSE
#    creating: development_set/bonzer-20090919-nnq/
#   inflating: development_set/bonzer-20090919-nnq/LICENSE
#    creating: development_set/bonzer-20090919-nma/
#   inflating: development_set/bonzer-20090919-nma/LICENSE
#    creating: development_set/bonzer-20090919-llm/
#   inflating: development_set/bonzer-20090919-llm/LICENSE
#    creating: development_set/bonzer-20090919-lft/
#   inflating: development_set/bonzer-20090919-lft/LICENSE
#    creating: development_set/bonzer-20090919-kbs/
#   inflating: development_set/bonzer-20090919-kbs/LICENSE
#    creating: development_set/bonzer-20090919-jxn/
#   inflating: development_set/bonzer-20090919-jxn/LICENSE
#    creating: development_set/bonzer-20090919-izn/
#   inflating: development_set/bonzer-20090919-izn/LICENSE
#    creating: development_set/bonzer-20090919-ijn/
#   inflating: development_set/bonzer-20090919-ijn/LICENSE
#    creating: development_set/bonzer-20090919-hhb/
#   inflating: development_set/bonzer-20090919-hhb/LICENSE
#    creating: development_set/bonzer-20090919-hbm/
#   inflating: development_set/bonzer-20090919-hbm/LICENSE
#    creating: development_set/bonzer-20090919-fxu/
#   inflating: development_set/bonzer-20090919-fxu/LICENSE
#    creating: development_set/bonzer-20090919-fxc/
#   inflating: development_set/bonzer-20090919-fxc/LICENSE
#    creating: development_set/bonzer-20090919-fot/
#   inflating: development_set/bonzer-20090919-fot/LICENSE
#    creating: development_set/bonzer-20090919-fir/
#   inflating: development_set/bonzer-20090919-fir/LICENSE
#    creating: development_set/bonzer-20090919-fau/
#   inflating: development_set/bonzer-20090919-fau/LICENSE
#    creating: development_set/bonzer-20090919-ecs/
#   inflating: development_set/bonzer-20090919-ecs/LICENSE
#    creating: development_set/bonzer-20090919-eca/
#   inflating: development_set/bonzer-20090919-eca/LICENSE
#    creating: development_set/bonzer-20090919-dwe/
#   inflating: development_set/bonzer-20090919-dwe/LICENSE
#    creating: development_set/bonzer-20090919-dfa/
#   inflating: development_set/bonzer-20090919-dfa/LICENSE
#    creating: development_set/bonzer-20090919-cox/
#   inflating: development_set/bonzer-20090919-cox/LICENSE
#    creating: development_set/bonzer-20090919-ccj/
#   inflating: development_set/bonzer-20090919-ccj/LICENSE
#    creating: development_set/bonzer-20090919-btg/
#   inflating: development_set/bonzer-20090919-btg/LICENSE
#    creating: development_set/bobriva123-20100611-cuz/
#   inflating: development_set/bobriva123-20100611-cuz/LICENSE
#    creating: development_set/BobHallstrom-20150105-zdp/
#   inflating: development_set/BobHallstrom-20150105-zdp/LICENSE
#    creating: development_set/BobHallstrom-20150105-uii/
#   inflating: development_set/BobHallstrom-20150105-uii/LICENSE
#    creating: development_set/BobHallstrom-20150105-tmy/
#   inflating: development_set/BobHallstrom-20150105-tmy/LICENSE
#    creating: development_set/Bob-20100106-mwu/
#   inflating: development_set/Bob-20100106-mwu/LICENSE
#    creating: development_set/bluSch-20100525-bqg/
#   inflating: development_set/bluSch-20100525-bqg/LICENSE
#    creating: development_set/bluepeppers-20091102-nkj/
#   inflating: development_set/bluepeppers-20091102-nkj/LICENSE
#    creating: development_set/bluepeppers-20091101-tyt/
#   inflating: development_set/bluepeppers-20091101-tyt/LICENSE
#    creating: development_set/bluepeppers-20091030-kqs/
#   inflating: development_set/bluepeppers-20091030-kqs/LICENSE
#    creating: development_set/bluefox83-20080413-bwq/
#   inflating: development_set/bluefox83-20080413-bwq/LICENSE
#    creating: development_set/BlueB-20090727-poc/
#   inflating: development_set/BlueB-20090727-poc/LICENSE
#    creating: development_set/BlueB-20090727-ckj/
#   inflating: development_set/BlueB-20090727-ckj/LICENSE
#    creating: development_set/BlueAgent-20120819-fjr/
#   inflating: development_set/BlueAgent-20120819-fjr/LICENSE
#    creating: development_set/BlueAgent-20120819-dok/
#   inflating: development_set/BlueAgent-20120819-dok/LICENSE
#    creating: development_set/bloomtom-20080612-vya/
#   inflating: development_set/bloomtom-20080612-vya/LICENSE
#    creating: development_set/bloomtom-20080612-stx/
#   inflating: development_set/bloomtom-20080612-stx/LICENSE
#    creating: development_set/bloomtom-20080612-pfg/
#   inflating: development_set/bloomtom-20080612-pfg/LICENSE
#    creating: development_set/bloomtom-20080612-mvm/
#   inflating: development_set/bloomtom-20080612-mvm/LICENSE
#    creating: development_set/blood-20100308-gbb/
#   inflating: development_set/blood-20100308-gbb/LICENSE
#    creating: development_set/BlindPilot-20100610-ulk/
#   inflating: development_set/BlindPilot-20100610-ulk/LICENSE
#    creating: development_set/BlindPilot-20100610-kko/
#   inflating: development_set/BlindPilot-20100610-kko/LICENSE
#    creating: development_set/BlindPilot-20100610-hnf/
#   inflating: development_set/BlindPilot-20100610-hnf/LICENSE
#    creating: development_set/BlindPilot-20100610-bzv/
#   inflating: development_set/BlindPilot-20100610-bzv/LICENSE
#    creating: development_set/BlindPilot-20100610-ama/
#   inflating: development_set/BlindPilot-20100610-ama/LICENSE
#    creating: development_set/Blenderkitty-20090615-ytz/
#   inflating: development_set/Blenderkitty-20090615-ytz/LICENSE
#    creating: development_set/Blenderkitty-20090615-tsi/
#   inflating: development_set/Blenderkitty-20090615-tsi/LICENSE
#    creating: development_set/Blenderkitty-20090615-svy/
#   inflating: development_set/Blenderkitty-20090615-svy/LICENSE
#    creating: development_set/Blenderkitty-20090615-rjb/
#   inflating: development_set/Blenderkitty-20090615-rjb/LICENSE
#    creating: development_set/Blenderkitty-20090615-qcv/
#   inflating: development_set/Blenderkitty-20090615-qcv/LICENSE
#    creating: development_set/Blackdrive-20080605-vwx/
#   inflating: development_set/Blackdrive-20080605-vwx/LICENSE
#    creating: development_set/Bitbrit-20090528-yit/
#   inflating: development_set/Bitbrit-20090528-yit/LICENSE
#    creating: development_set/Bitbrit-20090528-fsw/
#   inflating: development_set/Bitbrit-20090528-fsw/LICENSE
#    creating: development_set/BillMorgan-20120306-aef/
#   inflating: development_set/BillMorgan-20120306-aef/LICENSE
#    creating: development_set/BigMick-20090919-pvv/
#   inflating: development_set/BigMick-20090919-pvv/LICENSE
#    creating: development_set/bigmbywater-20100821-wsn/
#   inflating: development_set/bigmbywater-20100821-wsn/LICENSE
#    creating: development_set/bigmbywater-20100821-atk/
#   inflating: development_set/bigmbywater-20100821-atk/LICENSE
#    creating: development_set/bhuvan-20091111-cil/
#   inflating: development_set/bhuvan-20091111-cil/LICENSE
#    creating: development_set/BhushanNKIITBombay-20140219-bbj/
#   inflating: development_set/BhushanNKIITBombay-20140219-bbj/LICENSE
#    creating: development_set/bhavanikrishna-20100108-kth/
#   inflating: development_set/bhavanikrishna-20100108-kth/LICENSE
#    creating: development_set/bhart-20100108-yqc/
#   inflating: development_set/bhart-20100108-yqc/LICENSE
#    creating: development_set/bhart-20100108-xpl/
#   inflating: development_set/bhart-20100108-xpl/LICENSE
#    creating: development_set/bhart-20100108-uhg/
#   inflating: development_set/bhart-20100108-uhg/LICENSE
#    creating: development_set/bhart-20100108-nrx/
#   inflating: development_set/bhart-20100108-nrx/LICENSE
#    creating: development_set/bhart-20100108-hch/
#   inflating: development_set/bhart-20100108-hch/LICENSE
#    creating: development_set/bhart-20100108-dsa/
#   inflating: development_set/bhart-20100108-dsa/LICENSE
#    creating: development_set/bhart-20100106-yty/
#   inflating: development_set/bhart-20100106-yty/LICENSE
#    creating: development_set/bhart-20100106-wrw/
#   inflating: development_set/bhart-20100106-wrw/LICENSE
#    creating: development_set/bhart-20100106-tlh/
#   inflating: development_set/bhart-20100106-tlh/LICENSE
#    creating: development_set/bhart-20100106-rfx/
#   inflating: development_set/bhart-20100106-rfx/LICENSE
#    creating: development_set/bhart-20100106-qqz/
#   inflating: development_set/bhart-20100106-qqz/LICENSE
#    creating: development_set/bhart-20100106-qib/
#   inflating: development_set/bhart-20100106-qib/LICENSE
#    creating: development_set/bhart-20100106-pvf/
#   inflating: development_set/bhart-20100106-pvf/LICENSE
#    creating: development_set/bhart-20100106-mal/
#   inflating: development_set/bhart-20100106-mal/LICENSE
#    creating: development_set/bhart-20100106-lpu/wav/
#   inflating: development_set/bhart-20100106-lpu/wav/b0265.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0264.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0263.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0262.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0261.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0260.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0259.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0258.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0257.wav
#   inflating: development_set/bhart-20100106-lpu/wav/b0256.wav
#    creating: development_set/bhart-20100106-lpu/etc/
#   inflating: development_set/bhart-20100106-lpu/etc/README
#   inflating: development_set/bhart-20100106-lpu/etc/prompts-original
#   inflating: development_set/bhart-20100106-lpu/etc/PROMPTS
#   inflating: development_set/bhart-20100106-lpu/etc/HVite_log
#   inflating: development_set/bhart-20100106-lpu/etc/HDMan_log
#   inflating: development_set/bhart-20100106-lpu/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-lpu/etc/audiofile_details
#    creating: development_set/bhart-20100106-ldp/wav/
#   inflating: development_set/bhart-20100106-ldp/wav/rb-37.wav
#   inflating: development_set/bhart-20100106-ldp/wav/rb-36.wav
#   inflating: development_set/bhart-20100106-ldp/wav/rb-35.wav
#   inflating: development_set/bhart-20100106-ldp/wav/rb-34.wav
#   inflating: development_set/bhart-20100106-ldp/wav/rb-33.wav
#   inflating: development_set/bhart-20100106-ldp/wav/rb-32.wav
#   inflating: development_set/bhart-20100106-ldp/wav/rb-31.wav
#   inflating: development_set/bhart-20100106-ldp/wav/a0003.wav
#   inflating: development_set/bhart-20100106-ldp/wav/a0002.wav
#   inflating: development_set/bhart-20100106-ldp/wav/a0001.wav
#    creating: development_set/bhart-20100106-ldp/etc/
#   inflating: development_set/bhart-20100106-ldp/etc/README
#   inflating: development_set/bhart-20100106-ldp/etc/prompts-original
#   inflating: development_set/bhart-20100106-ldp/etc/PROMPTS
#   inflating: development_set/bhart-20100106-ldp/etc/HVite_log
#   inflating: development_set/bhart-20100106-ldp/etc/HDMan_log
#   inflating: development_set/bhart-20100106-ldp/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-ldp/etc/audiofile_details
#    creating: development_set/bhart-20100106-kab/wav/
#   inflating: development_set/bhart-20100106-kab/wav/b0044.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0043.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0042.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0041.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0040.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0039.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0038.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0037.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0036.wav
#   inflating: development_set/bhart-20100106-kab/wav/b0035.wav
#    creating: development_set/bhart-20100106-kab/etc/
#   inflating: development_set/bhart-20100106-kab/etc/README
#   inflating: development_set/bhart-20100106-kab/etc/prompts-original
#   inflating: development_set/bhart-20100106-kab/etc/PROMPTS
#   inflating: development_set/bhart-20100106-kab/etc/HVite_log
#   inflating: development_set/bhart-20100106-kab/etc/HDMan_log
#   inflating: development_set/bhart-20100106-kab/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-kab/etc/audiofile_details
#    creating: development_set/bhart-20100106-jot/wav/
#   inflating: development_set/bhart-20100106-jot/wav/a0161.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0160.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0159.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0158.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0157.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0156.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0155.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0154.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0153.wav
#   inflating: development_set/bhart-20100106-jot/wav/a0152.wav
#    creating: development_set/bhart-20100106-jot/etc/
#   inflating: development_set/bhart-20100106-jot/etc/README
#   inflating: development_set/bhart-20100106-jot/etc/prompts-original
#   inflating: development_set/bhart-20100106-jot/etc/PROMPTS
#   inflating: development_set/bhart-20100106-jot/etc/HVite_log
#   inflating: development_set/bhart-20100106-jot/etc/HDMan_log
#   inflating: development_set/bhart-20100106-jot/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-jot/etc/audiofile_details
#    creating: development_set/bhart-20100106-joc/wav/
#   inflating: development_set/bhart-20100106-joc/wav/b0261.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0260.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0259.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0258.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0257.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0256.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0255.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0254.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0253.wav
#   inflating: development_set/bhart-20100106-joc/wav/b0252.wav
#    creating: development_set/bhart-20100106-joc/etc/
#   inflating: development_set/bhart-20100106-joc/etc/README
#   inflating: development_set/bhart-20100106-joc/etc/prompts-original
#   inflating: development_set/bhart-20100106-joc/etc/PROMPTS
#   inflating: development_set/bhart-20100106-joc/etc/HVite_log
#   inflating: development_set/bhart-20100106-joc/etc/HDMan_log
#   inflating: development_set/bhart-20100106-joc/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-joc/etc/audiofile_details
#    creating: development_set/bhart-20100106-giy/wav/
#   inflating: development_set/bhart-20100106-giy/wav/a0087.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0086.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0085.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0084.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0083.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0082.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0081.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0080.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0079.wav
#   inflating: development_set/bhart-20100106-giy/wav/a0078.wav
#    creating: development_set/bhart-20100106-giy/etc/
#   inflating: development_set/bhart-20100106-giy/etc/README
#   inflating: development_set/bhart-20100106-giy/etc/prompts-original
#   inflating: development_set/bhart-20100106-giy/etc/PROMPTS
#   inflating: development_set/bhart-20100106-giy/etc/HVite_log
#   inflating: development_set/bhart-20100106-giy/etc/HDMan_log
#   inflating: development_set/bhart-20100106-giy/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-giy/etc/audiofile_details
#    creating: development_set/bhart-20100106-djk/wav/
#   inflating: development_set/bhart-20100106-djk/wav/a0011.wav
#   inflating: development_set/bhart-20100106-djk/wav/a0010.wav
#   inflating: development_set/bhart-20100106-djk/wav/a0009.wav
#   inflating: development_set/bhart-20100106-djk/wav/a0008.wav
#   inflating: development_set/bhart-20100106-djk/wav/a0007.wav
#   inflating: development_set/bhart-20100106-djk/wav/a0006.wav
#   inflating: development_set/bhart-20100106-djk/wav/a0005.wav
#   inflating: development_set/bhart-20100106-djk/wav/a
etc/GPL_license.txt
#   inflating: development_set/bhart-20100108-yqc/etc/audiofile_details
#    creating: development_set/bhart-20100108-xpl/wav/
#   inflating: development_set/bhart-20100108-xpl/wav/rb-28.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-27.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-26.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-25.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-24.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-23.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-22.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-21.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-20.wav
#   inflating: development_set/bhart-20100108-xpl/wav/rb-19.wav
#    creating: development_set/bhart-20100108-xpl/etc/
#   inflating: development_set/bhart-20100108-xpl/etc/README
#   inflating: development_set/bhart-20100108-xpl/etc/prompts-original
#   inflating: development_set/bhart-20100108-xpl/etc/PROMPTS
#   inflating: development_set/bhart-20100108-xpl/etc/HVite_log
#   inflating: development_set/bhart-20100108-xpl/etc/HDMan_log
#   inflating: development_set/bhart-20100108-xpl/etc/GPL_license.txt
#   inflating: development_set/bhart-20100108-xpl/etc/audiofile_details
#    creating: development_set/bhart-20100108-uhg/wav/
#   inflating: development_set/bhart-20100108-uhg/wav/b0391.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0390.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0389.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0388.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0387.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0386.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0385.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0384.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0383.wav
#   inflating: development_set/bhart-20100108-uhg/wav/b0382.wav
#    creating: development_set/bhart-20100108-uhg/etc/
#   inflating: development_set/bhart-20100108-uhg/etc/README
#   inflating: development_set/bhart-20100108-uhg/etc/prompts-original
#   inflating: development_set/bhart-20100108-uhg/etc/PROMPTS
#   inflating: development_set/bhart-20100108-uhg/etc/HVite_log
#   inflating: development_set/bhart-20100108-uhg/etc/HDMan_log
#   inflating: development_set/bhart-20100108-uhg/etc/GPL_license.txt
#   inflating: development_set/bhart-20100108-uhg/etc/audiofile_details
#    creating: development_set/bhart-20100108-nrx/wav/
#   inflating: development_set/bhart-20100108-nrx/wav/rp-17.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-16.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-15.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-14.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-13.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-12.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-11.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-10.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-09.wav
#   inflating: development_set/bhart-20100108-nrx/wav/rp-08.wav
#    creating: development_set/bhart-20100108-nrx/etc/
#   inflating: development_set/bhart-20100108-nrx/etc/README
#   inflating: development_set/bhart-20100108-nrx/etc/prompts-original
#   inflating: development_set/bhart-20100108-nrx/etc/PROMPTS
#   inflating: development_set/bhart-20100108-nrx/etc/HVite_log
#   inflating: development_set/bhart-20100108-nrx/etc/HDMan_log
#   inflating: development_set/bhart-20100108-nrx/etc/GPL_license.txt
#   inflating: development_set/bhart-20100108-nrx/etc/audiofile_details
#    creating: development_set/bhart-20100108-hch/wav/
#   inflating: development_set/bhart-20100108-hch/wav/a0229.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0228.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0227.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0226.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0225.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0224.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0223.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0222.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0221.wav
#   inflating: development_set/bhart-20100108-hch/wav/a0220.wav
#    creating: development_set/bhart-20100108-hch/etc/
#   inflating: development_set/bhart-20100108-hch/etc/README
#   inflating: development_set/bhart-20100108-hch/etc/prompts-original
#   inflating: development_set/bhart-20100108-hch/etc/PROMPTS
#   inflating: development_set/bhart-20100108-hch/etc/HVite_log
#   inflating: development_set/bhart-20100108-hch/etc/HDMan_log
#   inflating: development_set/bhart-20100108-hch/etc/GPL_license.txt
#   inflating: development_set/bhart-20100108-hch/etc/audiofile_details
#    creating: development_set/bhart-20100108-dsa/wav/
#   inflating: development_set/bhart-20100108-dsa/wav/a0569.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0568.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0567.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0566.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0565.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0564.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0563.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0562.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0561.wav
#   inflating: development_set/bhart-20100108-dsa/wav/a0560.wav
#    creating: development_set/bhart-20100108-dsa/etc/
#   inflating: development_set/bhart-20100108-dsa/etc/README
#   inflating: development_set/bhart-20100108-dsa/etc/prompts-original
#   inflating: development_set/bhart-20100108-dsa/etc/PROMPTS
#   inflating: development_set/bhart-20100108-dsa/etc/HVite_log
#   inflating: development_set/bhart-20100108-dsa/etc/HDMan_log
#   inflating: development_set/bhart-20100108-dsa/etc/GPL_license.txt
#   inflating: development_set/bhart-20100108-dsa/etc/audiofile_details
#    creating: development_set/bhart-20100106-yty/wav/
#   inflating: development_set/bhart-20100106-yty/wav/a0500.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0499.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0498.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0497.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0496.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0495.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0494.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0493.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0492.wav
#   inflating: development_set/bhart-20100106-yty/wav/a0491.wav
#    creating: development_set/bhart-20100106-yty/etc/
#   inflating: development_set/bhart-20100106-yty/etc/README
#   inflating: development_set/bhart-20100106-yty/etc/prompts-original
#   inflating: development_set/bhart-20100106-yty/etc/PROMPTS
#   inflating: development_set/bhart-20100106-yty/etc/HVite_log
#   inflating: development_set/bhart-20100106-yty/etc/HDMan_log
#   inflating: development_set/bhart-20100106-yty/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-yty/etc/audiofile_details
#    creating: development_set/bhart-20100106-wrw/wav/
#   inflating: development_set/bhart-20100106-wrw/wav/a0587.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0586.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0585.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0584.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0583.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0582.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0581.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0580.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0579.wav
#   inflating: development_set/bhart-20100106-wrw/wav/a0578.wav
#    creating: development_set/bhart-20100106-wrw/etc/
#   inflating: development_set/bhart-20100106-wrw/etc/README
#   inflating: development_set/bhart-20100106-wrw/etc/prompts-original
#   inflating: development_set/bhart-20100106-wrw/etc/PROMPTS
#   inflating: development_set/bhart-20100106-wrw/etc/HVite_log
#   inflating: development_set/bhart-20100106-wrw/etc/HDMan_log
#   inflating: development_set/bhart-20100106-wrw/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-wrw/etc/audiofile_details
#    creating: development_set/bhart-20100106-tlh/wav/
#   inflating: development_set/bhart-20100106-tlh/wav/b0020.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0019.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0018.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0017.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0016.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0015.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0014.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0013.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0012.wav
#   inflating: development_set/bhart-20100106-tlh/wav/b0011.wav
#    creating: development_set/bhart-20100106-tlh/etc/
#   inflating: development_set/bhart-20100106-tlh/etc/README
#   inflating: development_set/bhart-20100106-tlh/etc/prompts-original
#   inflating: development_set/bhart-20100106-tlh/etc/PROMPTS
#   inflating: development_set/bhart-20100106-tlh/etc/HVite_log
#   inflating: development_set/bhart-20100106-tlh/etc/HDMan_log
#   inflating: development_set/bhart-20100106-tlh/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-tlh/etc/audiofile_details
#    creating: development_set/bhart-20100106-rfx/wav/
#   inflating: development_set/bhart-20100106-rfx/wav/a0413.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0412.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0411.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0410.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0409.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0408.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0407.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0406.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0405.wav
#   inflating: development_set/bhart-20100106-rfx/wav/a0404.wav
#    creating: development_set/bhart-20100106-rfx/etc/
#   inflating: development_set/bhart-20100106-rfx/etc/README
#   inflating: development_set/bhart-20100106-rfx/etc/prompts-original
#   inflating: development_set/bhart-20100106-rfx/etc/PROMPTS
#   inflating: development_set/bhart-20100106-rfx/etc/HVite_log
#   inflating: development_set/bhart-20100106-rfx/etc/HDMan_log
#   inflating: development_set/bhart-20100106-rfx/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-rfx/etc/audiofile_details
#    creating: development_set/bhart-20100106-qqz/wav/
#   inflating: development_set/bhart-20100106-qqz/wav/b0012.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0011.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0010.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0009.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0008.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0007.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0006.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0005.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0004.wav
#   inflating: development_set/bhart-20100106-qqz/wav/b0003.wav
#    creating: development_set/bhart-20100106-qqz/etc/
#   inflating: development_set/bhart-20100106-qqz/etc/README
#   inflating: development_set/bhart-20100106-qqz/etc/prompts-original
#   inflating: development_set/bhart-20100106-qqz/etc/PROMPTS
#   inflating: development_set/bhart-20100106-qqz/etc/HVite_log
#   inflating: development_set/bhart-20100106-qqz/etc/HDMan_log
#   inflating: development_set/bhart-20100106-qqz/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-qqz/etc/audiofile_details
#    creating: development_set/bhart-20100106-qib/wav/
#   inflating: development_set/bhart-20100106-qib/wav/a0019.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0018.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0017.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0016.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0015.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0014.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0013.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0012.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0011.wav
#   inflating: development_set/bhart-20100106-qib/wav/a0010.wav
#    creating: development_set/bhart-20100106-qib/etc/
#   inflating: development_set/bhart-20100106-qib/etc/README
#   inflating: development_set/bhart-20100106-qib/etc/prompts-original
#   inflating: development_set/bhart-20100106-qib/etc/PROMPTS
#   inflating: development_set/bhart-20100106-qib/etc/HVite_log
#   inflating: development_set/bhart-20100106-qib/etc/HDMan_log
#   inflating: development_set/bhart-20100106-qib/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-qib/etc/audiofile_details
#    creating: development_set/bhart-20100106-pvf/wav/
#   inflating: development_set/bhart-20100106-pvf/wav/a0064.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0063.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0062.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0061.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0060.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0059.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0058.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0057.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0056.wav
#   inflating: development_set/bhart-20100106-pvf/wav/a0055.wav
#    creating: development_set/bhart-20100106-pvf/etc/
#   inflating: development_set/bhart-20100106-pvf/etc/README
#   inflating: development_set/bhart-20100106-pvf/etc/prompts-original
#   inflating: development_set/bhart-20100106-pvf/etc/PROMPTS
#   inflating: development_set/bhart-20100106-pvf/etc/HVite_log
#   inflating: development_set/bhart-20100106-pvf/etc/HDMan_log
#   inflating: development_set/bhart-20100106-pvf/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-pvf/etc/audiofile_details
#    creating: development_set/bhart-20100106-mal/wav/
#   inflating: development_set/bhart-20100106-mal/wav/a0494.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0493.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0492.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0491.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0490.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0489.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0488.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0487.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0486.wav
#   inflating: development_set/bhart-20100106-mal/wav/a0485.wav
#    creating: development_set/bhart-20100106-mal/etc/
#   inflating: development_set/bhart-20100106-mal/etc/README
#   inflating: development_set/bhart-20100106-mal/etc/prompts-original
#   inflating: development_set/bhart-20100106-mal/etc/PROMPTS
#   inflating: development_set/bhart-20100106-mal/etc/HVite_log
#   inflating: development_set/bhart-20100106-mal/etc/HDMan_log
#   inflating: development_set/bhart-20100106-mal/etc/GPL_license.txt
#   inflating: development_set/bhart-20100106-mal/etc/audiofile_details

# %% [markdown]
# The below data-sets can be downloaded from here.
#
#   Training corpus : It has been developed from audios taken from ‘on-line VoxForge speech database’ and consists of 5 speech utterances for each speaker, spoken by 34 speakers (i.e, 20-30 seconds/speaker).
#
#   Test corpus: This consists of remaining 5 unseen utterances of the same 34 speakers taken in train corpus.  All audio files are of 10 seconds duration and are sampled at 16000 Hz.

# %% [markdown]
# I will strongly recommend you to read our previous post ‘Voice Gender Detection’ as a brief primer about how to work with speech signals are explained there. We have also discussed about extracting a popular speech feature, Mel Frequency Cepstrum Coefficients (MFCCs) previously. A GMM will take as input the MFCCs and derivatives of MFCCs of the training samples of a speaker and will try to learn their distribution, which will be representative of that speaker. A typical speaker identification process can be shown by flow diagram below.

# %% [markdown]
# While testing when the speaker of a new voice sample is to be identified, first the 40-dimensional feature (MFCCs + delta MFCC) of the sample will be extracted and then the trained speaker GMM models will be used to calculate the scores of the features for all the models. Speaker model with the maximum score is predicted as the identified speaker of the test speech. Having said that we will go through the python implementation of the following steps:
#
#     40-Dimensional Feature Extraction
#     Training Speaker Models.
#     Evaluating Performance on test set

# %% [markdown]
# Feature Extraction.
#
# We extract 40-dimensional features from speech frames. There are 20 MFCC features and 20 derivatives of MFCC features. The derivatives of MFCCs provides the information of dynamics of MFCCs over the time. It turns out that calculating the delta-MFCC and appending them to the original MFCC features (20-dimenaionl) increases the performance in lot of speech analytics applications. To calculate delta features from MFCCs, we apply the following equation.

# %% [markdown]
# The below python functions extracts MFCC features and derives delta coefficients from from audio signal.

# %%
import numpy as np
from sklearn import preprocessing
import python_speech_features as mfcc
 
def calculate_delta(array):
    """Calculate and returns the delta of given feature vector matrix"""
    rows,cols = array.shape
    deltas = np.zeros((rows,20))
    N = 2
    for i in range(rows):
        index = []
        j = 1
        while(j <= N):
            if(i-j < 0):
                first = 0
            else:
                first = i-j
            if(i+j > rows -1):
                second = rows -1
            else:
                second = i+j
            index.append((second,first))
            j+=1
        deltas[i] = ( array[index[0][0]]-array[index[0][1]] + (2 * (array[index[1][0]]-array[index[1][1]])) ) / 10
    return deltas
 
def extract_features(audio,rate):
    """extract 20 dim mfcc features from an audio, performs CMS and combines
    delta to make it 40 dim feature vector"""   
 
    mfcc_feat = mfcc.mfcc(audio,rate, 0.025, 0.01,20,appendEnergy = True)
    mfcc_feat = preprocessing.scale(mfcc_feat)
    delta = calculate_delta(mfcc_feat)
    combined = np.hstack((mfcc_feat,delta))
    return combined

# %% [markdown]
# 2. Training Speaker Models.
#
# As we know, There are 34 distinct speakers in training corpus which are taken from lots of speaker provided by VoxForge. The path of all the audio files (5 per speaker) utilized for training are given in this file. Usually there is a very important step called pre-processing, aslo known as voice activity detection(VAD) which includes noise removal and silence truncation from the audios. I have assumed that there is no requirement of performing VAD here.
#
# In order to build a speaker identification system from the above extracted features, we need to model all the speakers independently now. We employ GMMs for this task.
#
# A Gaussian mixture model is a probabilistic clustering model for representing the presence of sub-populations within an overall population.  The idea of training a GMM is to approximate the probability distribution of a class by a linear combination of ‘k’ Gaussian distributions/clusters, also called the components of the GMM. The likelihood of data points (feature vectors) for a model is given by following equation:

# %% [markdown]
# Python’s sklearn.mixture package is used by us to learn a GMM from the features matrix containing the 40 dimensional MFCC and delta-MFCC features. More about sklearn GMM can be read from section 3 of our previous post ‘Voice Gender Detection‘. The following Python code is used to train the GMM speaker models with 16 components. The code is run once for each speaker and train_file is variable which has text filename containing path to all the audios for the respective speaker. Also, you have to create a “speaker_models” directory where all the models will be dumped after training.

# %%
! wget https://www.dropbox.com/s/iu12o5sdramh7wo/development_set_enroll.txt?dl=0
# Out:
# --2020-05-15 05:22:32--  https://www.dropbox.com/s/iu12o5sdramh7wo/development_set_enroll.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/iu12o5sdramh7wo/development_set_enroll.txt [following]
# --2020-05-15 05:22:32--  https://www.dropbox.com/s/raw/iu12o5sdramh7wo/development_set_enroll.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc93ed550f1294b9f7ef7430b296.dl.dropboxusercontent.com/cd/0/inline/A3sqbFShRNGGDywqn-RnkpUAFgL_27RXDuHj2OajOFS9O0R77CyM5GYp2C9sZgy5YJ84XSsid8t9vr25c7vSxLs2IfonYgGe_peOjmAjilqLRRubB5gL_oOhheGrlSsKJT8/file# [following]
# --2020-05-15 05:22:32--  https://uc93ed550f1294b9f7ef7430b296.dl.dropboxusercontent.com/cd/0/inline/A3sqbFShRNGGDywqn-RnkpUAFgL_27RXDuHj2OajOFS9O0R77CyM5GYp2C9sZgy5YJ84XSsid8t9vr25c7vSxLs2IfonYgGe_peOjmAjilqLRRubB5gL_oOhheGrlSsKJT8/file
# Resolving uc93ed550f1294b9f7ef7430b296.dl.dropboxusercontent.com (uc93ed550f1294b9f7ef7430b296.dl.dropboxusercontent.com)... 162.125.3.6, 2620:100:601f:6::a27d:906
# Connecting to uc93ed550f1294b9f7ef7430b296.dl.dropboxusercontent.com (uc93ed550f1294b9f7ef7430b296.dl.dropboxusercontent.com)|162.125.3.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5993 (5.9K) [text/plain]
# Saving to: ‘development_set_enroll.txt?dl=0’
#
# development_set_enr 100%[===================>]   5.85K  --.-KB/s    in 0s
#
# 2020-05-15 05:22:33 (708 MB/s) - ‘development_set_enroll.txt?dl=0’ saved [5993/5993]

# %%
import pickle
import numpy as np
from scipy.io.wavfile import read
from sklearn.mixture import GaussianMixture as GMM
import warnings
import numpy as np
from sklearn import preprocessing
import python_speech_features as mfcc
warnings.filterwarnings("ignore")
 
#path to training data
source   = "/content/development_set/"  
 
#path where training speakers will be saved
dest = "/content/speaker_models/"
train_file = "/content/development_set_enroll.txt"
file_paths = open(train_file,'r')
 
count = 1
# Extracting features for each speaker (5 files per speakers)
features = np.asarray(())
for path in file_paths:
    path = path.strip()
    #print(path)
    path=path.replace("\\", "/")
    # read the audio
    sr,audio = read(source + path)
 
    # extract 40 dimensional MFCC & delta MFCC features
    vector   = extract_features(audio,sr)
 
    if features.size == 0:
        features = vector
    else:
        features = np.vstack((features, vector))
    # when features of 5 files of speaker are concatenated, then do model training
    if count == 5:
        gmm = GMM(n_components = 16, covariance_type='diag',n_init = 3)
        gmm.fit(features)
 
        # dumping the trained gaussian model
        picklefile = path.split("-")[0]+".gmm"
        pickle.dump(gmm,open(dest + picklefile,'wb'))
        print('+ modeling completed for speaker:',picklefile," with data point = ",features.shape)
        features = np.asarray(())
        count = 0
    count = count + 1
# Out:
# + modeling completed for speaker: anthonyschaller.gmm  with data point =  (1595, 40)
# + modeling completed for speaker: Apple_Eater.gmm  with data point =  (2077, 40)
# + modeling completed for speaker: Ara.gmm  with data point =  (3644, 40)
# + modeling completed for speaker: argail.gmm  with data point =  (2468, 40)
# + modeling completed for speaker: ariyan.gmm  with data point =  (2506, 40)
# + modeling completed for speaker: arjuan.gmm  with data point =  (2707, 40)
# + modeling completed for speaker: Artem.gmm  with data point =  (2794, 40)
# + modeling completed for speaker: arthur.gmm  with data point =  (3782, 40)
# + modeling completed for speaker: artk.gmm  with data point =  (3369, 40)
# + modeling completed for speaker: arun.gmm  with data point =  (3031, 40)
# + modeling completed for speaker: arvala.gmm  with data point =  (2718, 40)
# + modeling completed for speaker: asalkeld.gmm  with data point =  (3294, 40)
# + modeling completed for speaker: asladic.gmm  with data point =  (1743, 40)
# + modeling completed for speaker: AslakKnutsen.gmm  with data point =  (2444, 40)
# + modeling completed for speaker: asp.gmm  with data point =  (2506, 40)
# + modeling completed for speaker: AT.gmm  with data point =  (2694, 40)
# + modeling completed for speaker: atamur.gmm  with data point =  (2056, 40)
# + modeling completed for speaker: ataru80.gmm  with data point =  (2831, 40)
# + modeling completed for speaker: atterer.gmm  with data point =  (2391, 40)
# + modeling completed for speaker: audioodyssey.gmm  with data point =  (3219, 40)
# + modeling completed for speaker: avsa242.gmm  with data point =  (2708, 40)
# + modeling completed for speaker: ax.gmm  with data point =  (2719, 40)
# + modeling completed for speaker: axllaruse.gmm  with data point =  (3381, 40)
# + modeling completed for speaker: azmisov.gmm  with data point =  (2195, 40)
# + modeling completed for speaker: B.gmm  with data point =  (2042, 40)
# + modeling completed for speaker: bachroxx.gmm  with data point =  (1955, 40)
# + modeling completed for speaker: bae.gmm  with data point =  (2719, 40)
# + modeling completed for speaker: Bahoke.gmm  with data point =  (2194, 40)
# + modeling completed for speaker: Bareford.gmm  with data point =  (2844, 40)
# + modeling completed for speaker: bart.gmm  with data point =  (2079, 40)
# + modeling completed for speaker: Bassel.gmm  with data point =  (2831, 40)
# + modeling completed for speaker: beady.gmm  with data point =  (2409, 40)
# + modeling completed for speaker: beez1717.gmm  with data point =  (2132, 40)
# + modeling completed for speaker: belmontguy.gmm  with data point =  (2594, 40)

# %% [markdown]
# ## 3. Evaluating Performance on Test set.
#
# Test set consists of 5 unseen utterances of trained 34 speakers. The path of all the audio files (5 per speaker) utilized for evaluation are given in this file.
#
# Upon arrival of a test voice sample for speaker identification, we begin by extracting the 40 dimensional for it, with 25 ms frame size and 10 ms overlap between frames. Next we require the log likelihood scores for each frame of the sample, x_1, x_2, ... ,x_i , belonging to each speaker, ie, P(x_i|S_j) (for all j that belongs to S) is to be calculated. The likelihood of the frame being from a particular speaker is calculated by substituting the \mu and \Sigma of that speaker GMM model in likelihood equation shown in previous section. This is done for each of the ‘k’ Gaussian components in the model, and the weighted  sum of the ‘k’ likelihoods from the components is taken as per the weight ‘w ‘ parameter of the model. The logarithm operation when applied on the obtained sum gives us the log likelihood value for the frame. This is repeated for all the frames of the sample and the likelihoods of all the frames are added. The speaker model with highest likelihood score is considered as the identified speaker.
#
# The Python code given below predicts the speaker of the test audio.

# %%
! wget https://www.dropbox.com/s/9dg83clhvmm5d40/development_set_test.txt?dl=0
# Out:
# --2020-05-15 05:43:52--  https://www.dropbox.com/s/9dg83clhvmm5d40/development_set_test.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/9dg83clhvmm5d40/development_set_test.txt [following]
# --2020-05-15 05:43:52--  https://www.dropbox.com/s/raw/9dg83clhvmm5d40/development_set_test.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc1a1c40ae90dc4c4ea33068498.dl.dropboxusercontent.com/cd/0/inline/A3uFGXSXs5w3Aknw-4iRyHGF_kaYOTV14fqi0DZ-tg-UyjQPbqZZ75WMtajsl3wso962nng1fBJqX2hR0jRE5ToOri-_LnOHAIMILLXu4ch0U0-sWmS38L9p7NxgO9ZpHeo/file# [following]
# --2020-05-15 05:43:52--  https://ucc1a1c40ae90dc4c4ea33068498.dl.dropboxusercontent.com/cd/0/inline/A3uFGXSXs5w3Aknw-4iRyHGF_kaYOTV14fqi0DZ-tg-UyjQPbqZZ75WMtajsl3wso962nng1fBJqX2hR0jRE5ToOri-_LnOHAIMILLXu4ch0U0-sWmS38L9p7NxgO9ZpHeo/file
# Resolving ucc1a1c40ae90dc4c4ea33068498.dl.dropboxusercontent.com (ucc1a1c40ae90dc4c4ea33068498.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:6018:6::a27d:306
# Connecting to ucc1a1c40ae90dc4c4ea33068498.dl.dropboxusercontent.com (ucc1a1c40ae90dc4c4ea33068498.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5993 (5.9K) [text/plain]
# Saving to: ‘development_set_test.txt?dl=0’
#
# development_set_tes 100%[===================>]   5.85K  --.-KB/s    in 0s
#
# 2020-05-15 05:43:53 (735 MB/s) - ‘development_set_test.txt?dl=0’ saved [5993/5993]

# %%
import os
import pickle
import numpy as np
from scipy.io.wavfile import read
import warnings
warnings.filterwarnings("ignore")
import time
 
#path to training data
source   = "/content/development_set/"
modelpath = "/content/speaker_models/"
test_file = "/content/development_set_test.txt"
file_paths = open(test_file,'r')
 
gmm_files = [os.path.join(modelpath,fname) for fname in
              os.listdir(modelpath) if fname.endswith('.gmm')]
 
#Load the Gaussian gender Models
models    = [pickle.load(open(fname,'rb')) for fname in gmm_files]
speakers   = [fname.split("/")[-1].split(".gmm")[0] for fname
              in gmm_files]
total_file=0
correct=0
wrong=0
# Read the test directory and get the list of test audio files
for path in file_paths:   
 
    path = path.strip()
    #print(path)
    path=path.replace("\\", "/")
    name = path.split('-')[0]
    total_file+=1
    sr,audio = read(source + path)
    vector   = extract_features(audio,sr)
 
    log_likelihood = np.zeros(len(models)) 
 
    for i in range(len(models)):
        gmm    = models[i]  #checking with each model one by one
        scores = np.array(gmm.score(vector))
        log_likelihood[i] = scores.sum()
 
    winner = np.argmax(log_likelihood)
    if(name==speakers[winner]):
      correct+=1
    else:
      wrong+=1
    #print("\tdetected as - ", speakers[winner])
    #time.sleep(1.0)
print("total no of files = ",total_file)
print("Correctly identified files = ", correct)
print("Wrong identification = ", wrong)
# Out:
# total no of files =  170
# Correctly identified files =  169
# Wrong identification =  1

# %% [markdown]
# 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
#
# if the above error occurs in pickle.load, it is because it was dumped in r format and was loaded in rb format. That is format mismatch. Load and dump in same format to remove the error

# %% [markdown]
# Results and Conclusion
#
# This beginner’s approach performs with an in-set accuracy of 100%, identifying all the 170 speech utterances correctly. There are few reasons for such perfect result.
#
#   The unseen utterances of speakers taken from VoxForge are possibly of same channel or environment.
#
#   The evaluation task in performed on small dataset. Consider a data inflow where you are getting probably some thousands of calls in a day.
#
#   Consider the situation when we have to identify speakers from the set of 1000 speakers.
#
#   In this evaluation, we have not taken out-of-set speakers into account i.e. if the audio is not from any speaker still our system will identify it as one of speakers in trained set depending upon highest likelihood.
#
#   In the real environment, we may get more noisy and unclean data. Speaker identification system needs to be robust.
